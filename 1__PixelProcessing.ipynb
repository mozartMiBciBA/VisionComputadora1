# %% [markdown]
# <a href="https://colab.research.google.com/github/mozartMiBciBA/VisionComputadora1/blob/main/1__PixelProcessing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Pixel Processing | Image Processing I
#
# Fuente: https://www.youtube.com/watch?v=f-5l8Cdcb8k&list=PL2zRqk16wsdorCSZ5GWZQr1EMWXs2TDeu&index=2

# %% [markdown]
# First Principles of Computer Vision is a lecture series presented by Shree Nayar who is faculty in the Computer Science Department, School of Engineering and Applied Sciences, Columbia University. Computer Vision is the enterprise of building machines that “see.” This series focuses on the physical and mathematical underpinnings of vision and has been designed for students, practitioners, and enthusiasts who have no prior knowledge of computer vision.

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

img1 = cv2.imread('Fig0219.tif',0)
img2 = cv2.imread('Fig0219.tif',0)
#w1, h1 = img1.shape
#w2, h2 = img2.shape
#print ('w1', w1)
#
plt.imshow(img1, cmap='gray')
plt.title('Original')
plt.show()
print("img1[400][400]:", img1[400][400])
#print("img1[400][400]:", img1[400][400])
#print("img1[600][600]:", img1[600][600])

##### Suma
#SumA = cv2.add(img1,img2)
#SumA = cv2.add(img1,250)
###  Lighten (f + 128) ###
SumA = cv2.add(img1,128)

##### Resta

#RestA = cv2.absdiff(img1, img2)
#RestA = cv2.absdiff(img1, 50)

### Darken  ###
#RestA = cv2.absdiff(img1, 128)

### Invert  ###
RestA = cv2.absdiff(255,img1)

### División
### Low contrast (f/2)
DivisioN = cv2.divide(img1,2)


### Multiplicación ###
### High constrast (f * 2)
MultiplicacioN = cv2.multiply(img1,2)

### Multiplicación y adición
### Gray
### 0.3 * f_r + 0.6 * f_g + 0.1 * f_b



#plt.imshow(SumA, cmap='gray')
#plt.title('Suma')
#plt.show()
#print("SumA[0][0]:", SumA[0][0])
#print("SumA[400][400]:", SumA[400][400])
#print("SumA[600][600]:", SumA[600][600])


#plt.imshow(RestA, cmap='gray')
#plt.title('Resta')
#plt.show()
#print("RestA[0][0]:", RestA[0][0])
#print("RestA[400][400]:", RestA[400][400])
#print("RestA[600][600]:", RestA[600][600])

plt.show()
plt.subplot(2,2,1),plt.imshow(RestA, cmap='gray'), plt.title('RestA')
plt.xticks([]), plt.yticks([])
plt.subplot(2,2,2),plt.imshow(DivisioN, cmap='gray'), plt.title('Low contrast (f/2)')
plt.xticks([]), plt.yticks([])
plt.subplot(2,2,3),plt.imshow(MultiplicacioN, cmap='gray'), plt.title('High contrast (f*2)')
plt.xticks([]), plt.yticks([])
plt.subplot(2,2,4),plt.imshow(SumA, cmap='gray'), plt.title('SumA')
plt.xticks([]), plt.yticks([])
plt.show()
# Out:
# img1[400][400]: 222
